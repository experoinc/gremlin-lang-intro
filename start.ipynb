# %% [markdown]
# welcome intro text

# %%
import asyncio
import goblin  # provides aliases to common aiogremlin objects

loop = asyncio.get_event_loop()
remote_conn = loop.run_until_complete(
    goblin.DriverRemoteConnection.open(
        "http://localhost:8182", loop))
graph = driver.Graph()
g = goblin.traversal().withRemote(remote_conn)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Users/stevejpurves/anaconda3/lib/python3.5/site-packages/aiohttp/connector.py in _create_direct_connection(self, req)
#     665                     server_hostname=hinfo['hostname'] if sslcontext else None,
# --> 666                     local_addr=self._local_addr)
#     667                 has_cert = transp.get_extra_info('sslcontext')
#
# /Users/stevejpurves/anaconda3/lib/python3.5/asyncio/base_events.py in create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname)
#     694                 if len(exceptions) == 1:
# --> 695                     raise exceptions[0]
#     696                 else:
#
# ...
